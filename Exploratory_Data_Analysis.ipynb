# %%
# Exploratory data analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris = pd.read_csv("E:/datasets/Iris.csv")

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.plot(kind='scatter', x = 'SepalLengthCm', y = 'SepalWidthCm')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
sns.scatterplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
# purpose:- to identify which points can be easily separated

sns.pairplot(data=iris, hue='Species')

# %%
# sepal length and petal length can separate all 3 flowers pretty good
# but petal length and petal width is better

# %%
# univariate analysis

# %%
# histograms, cdf, pdf

# %%
setosa = iris.loc[iris['Species']=='Iris-setosa']
virginica = iris.loc[iris['Species']=='Iris-virginica']
versicolor = iris.loc[iris['Species']=='Iris-versicolor']

# %%
sns.FacetGrid(iris, hue="Species", height=5).map(sns.distplot, "PetalLengthCm").add_legend();
plt.show();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
print(np.median(iris['SepalLengthCm']),
np.mean(iris['SepalLengthCm']),
np.median(iris['PetalLengthCm']),
np.mean(iris['PetalLengthCm']),
np.std(iris['PetalLengthCm']))
# Out:
# 5.8 5.843333333333335 4.35 3.7586666666666693 1.7585291834055201

# %%
# cdf, pdf
count, bin_edges = np.histogram(setosa['PetalLengthCm'], bins=10)

# %%
print(count, bin_edges)
# Out:
# [ 1  1  2  7 12 14  7  4  0  2] [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
pdf = count/sum(counts)
cdf = np.cumsum(pdf)

# %%
plt.plot(pdf)
plt.plot(cdf)

# %%
# median, percentiles, 90 pertl, mad

# %%
print('\nmedian:')

print(np.median(setosa['PetalLengthCm']))
print(np.median(virginica['PetalLengthCm']))
print(np.median(versicolor['PetalLengthCm']))

print('\npercentiles:')

print(np.percentile(setosa['PetalLengthCm'], np.arange(0,100,23)))
print(np.percentile(virginica['PetalLengthCm'], np.arange(0,100,23)))
print(np.percentile(versicolor['PetalLengthCm'], np.arange(0,100,23)))

print('\n90th percentl:')

print(np.percentile(setosa['PetalLengthCm'], 90))
print(np.percentile(virginica['PetalLengthCm'], 90))
print(np.percentile(versicolor['PetalLengthCm'], 90))

print('\nmad:')

from statsmodels import robust
print(robust.mad(setosa['PetalLengthCm']))
print(robust.mad(virginica['PetalLengthCm']))
print(robust.mad(versicolor['PetalLengthCm']))
# Out:
# median:
# 1.5
# 5.55
# 4.35
#
# percentiles:
# [1.    1.4   1.454 1.5   1.7  ]
# [4.5   5.1   5.5   5.781 6.416]
# [3.    4.    4.254 4.5   4.808]
#
# 90th percentl:
# 1.7
# 6.31
# 4.8
#
# mad:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
sns.boxplot(data=iris, x='Species', y='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.violinplot(data=iris, x='Species', y='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.jointplot(x="SepalLengthCm", y="PetalLengthCm", data=setosa, kind="kde");
plt.show()
